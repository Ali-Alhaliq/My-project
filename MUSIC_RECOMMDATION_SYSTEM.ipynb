# %% [markdown]
# Import DataSet

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/spotify_millsongdata.csv')

# %%
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df =df.sample(10000).drop('link', axis=1).reset_index(drop=True)

# %%
df.shape
# Out:
# (10000, 3)

# %%
df.head(50)
# Out:
#                   artist                             song  \
# 0              Lady Gaga                  Sinner's Prayer
# 1             Tim McGraw       That's Why God Made Mexico
# 2           Wishbone Ash                   Sometime World
# 3                   INXS                What Would You Do
# 4   Allman Brothers Band          Ocean Awash The Gunwale
# 5                Squeeze                     Goodbye Girl
# 6             Perry Como         All I Do Is Dream Of You
# 7            Moody Blues              Want To Be With You
# 8              Aerosmith           Something's Gotta Give
# 9                Journey                    Signs Of Life
# 10     Dusty Springfield                    Another Night
# 11       Backstreet Boys               Climbing The Walls
# 12           Deep Purple                            Blind
# 13             Scorpions   As Soon As The Good Times Roll
# 14        Counting Crows            Einstein On The Beach
# 15         Gloria Gaynor                 Joy To The World
# 16          Van Morrison                     Glad Tidings
# 17                 Unkle                    Price You Pay
# 18        Michael Bolton      Can't Hold On, Can't Let Go
# 19            Neil Young              Are You Passionate?
# 20            Beach Boys                        In My Car
# 21         Willie Nelson              Building Heartaches
# 22            Carpenters                Winter Wonderland
# 23                Barbie                        Here I Am
# 24            Paul Simon              A Most Peculiar Man
# 25       Hillsong United                         Everyday
# 26             Radiohead              2HB (Venus In Furs)
# 27         Lenny Kravitz                   Let's Get High
# 28                 Kinks                   I Gotta Go Now
# 29              Flo-Rida                        Available
# 30          Foo Fighters                             Milk
# 31            Thin Lizzy                Got To Give It Up
# 32          Dire Straits                 Sultans Of Swing
# 33             Morrissey         Dear God, Please Help Me
# 34            Paul Simon                  Congratulations
# 35           Nina Simone  In The Evening By The Moonlight
# 36       John Mellencamp                           L.U.V.
# 37              Iggy Pop                        Bang Bang
# 38          Judas Priest                      Machine Man
# 39          Warren Zevon                         Gridlock
# 40             Lil Wayne                     Green Ranger
# 41              Westlife                          Forever
# 42        Ellie Goulding                      Midas Touch
# 43         Gino Vannelli                       Mardi Gras
# 44            Whitesnake               Still Of The Night
# 45       Waylon Jennings                    Can't You See
# 46                  Rush                    Sweet Miracle
# 47             Offspring                   Total Immortal
# 48       Christmas Songs         O Come, O Come, Emmanuel
# 49          Quarterflash                       Talk To Me
#
#                                                  text
# 0   [Verse 1]  \r\nI came down the mountain  \r\nD...
# 1   Margie said Roy you ain't listening to me  \r\...
# 2   I met a man who felt the same way,  \r\nThat t...
# 3   I've come a long way by car  \r\nThe road went...
# 4   Our lives are hanging in the balance  \r\nOr t...
# 5   I met her in a poolroom  \r\nHer name I didn't...
# 6   All I do is dream of you the whole night throu...
# 7   When I think of all the things that we've been...
# 8   Cyberotic head explode  \r\nInformation overlo...
# 9   It's been forty days since I heard from you th...
# 10  Find me a rose that never fades and dies  \r\n...
# 11  Close your eyes, make a wish  \r\nThis could l...
# 12  I see reflections in the water  \r\nAutumn col...
# 13  If you feel real sad sometimes  \r\nCaught in ...
# 14  Albert's always sincere, he's a sensitive type...
# 15  Joy to the world, the Lord is come  \r\nLet Ea...
# 16  And they'll lay you down low in the easy  \r\n...
# 17  No one can tell me just why it is  \r\nThat it...
# 18  Every time I think of you  \r\nMy heart starts...
# 19  Are you passionate?  \r\nAre you livin' like y...
# 20  When I'm behind the wheel  \r\nHorses of gas a...
# 21  Each time that I hold you close, here in my ar...
# 22  Sleigh bells ring  \r\n  \r\nAre you listening...
# 23  [Verse 1]  \r\nWhen I was young  \r\nI played ...
# 24  He was a most peculiar man  \r\nThat's what Mr...
# 25  What to say, Lord? It's  \r\nYou who gave me l...
# 26  Oh, I was moved by your screen dream  \r\nCell...
# 27  Let's go out  \r\nOn an ocean ride  \r\nLeave ...
# 28  I gotta go now, gotta go now  \r\nI gotta go n...
# 29  Ooh ooh ooh, ooh ooh ooh, ooh ooh ooh  \r\nOoh...
# 30  If I share powdered milk with you  \r\nI glue ...
# 31  [Chorus]  \r\nI've got to give it up I've got ...
# 32  You get a shiver in the dark,  \r\nIt's a rain...
# 33  I am walking through Rome  \r\nWith my heart o...
# 34  Congratulations!  \r\nOh, seems like you've do...
# 35  In the evening by the moonlight  \r\nWhen my m...
# 36  Guilty 'til proven innocent  \r\nI'm thinking ...
# 37  Well this ain't the right thing to do, so let'...
# 38  Licensed to kill  \r\nOn my 650 Bonneville  \r...
# 39  It's 5:00 P.M. on a weekday, friend  \r\nThere...
# 40  [J. Cole]  \r\nWhen this shit drop, I was like...
# 41    \r\n  \r\n  \r\n  \r\n  \r\n  \r\nI'll be lo...
# 42  You say you're going through changes  \r\nEver...
# 43  I broke the doldrums of my dreary dreams  \r\n...
# 44  In the still of the night  \r\nI hear the wolf...
# 45  Gonna catch a freight train as far as I can Lo...
# 46  I wasn't walking on water  \r\nI was standing ...
# 47  Hope unkown. Sometimes just waking is surreal....
# 48  O come, O come, Emmanuel  \r\nAnd ransom capti...
# 49  There's some out there tonight  \r\nWho's lost...

# %%
df.tail(5)
# Out:
#                     artist                    song  \
# 9995            Carpenters     When I Fall In Love
# 9996  Allman Brothers Band              Crazy Love
# 9997          Donna Summer          Grand Illusion
# 9998            Status Quo  Don't Think It Matters
# 9999       Robbie Williams        Life Thru A Lens
#
#                                                    text
# 9995  Maybe I'm old fashioned feeling as I do  \r\nM...
# 9996  Somewhere down on a back street  \r\nWay down ...
# 9997  Oh grand illusion, like to fade away  \r\nTake...
# 9998  Maybe I'm right, or maybe I'm wrong  \r\nI got...
# 9999  Wake up on Sunday morning  \r\nEverything feel...

# %%
df['text'][0]
# Out:
# "[Verse 1]  \r\nI came down the mountain  \r\nDraggin' our love affair  \r\nPut on a pretty little number  \r\nI'm wearing you still  \r\nIt was a hell of a scene at daddy's feast  \r\nNobody saw it coming, but the little red devil in me  \r\nHe has a funny way saying forever too fast  \r\nDon't get mad, can't blame a tramp  \r\nFor something he don't have  \r\nI get on my knees and beg you  \r\n  \r\n[Chorus]  \r\nHear my sinner's prayer  \r\nI am what I am  \r\nAnd I don't wanna break the heart of any other man  \r\nBut you, but you  \r\nHear my sinner's prayer  \r\nIt's the only one I know  \r\nIt sure as hell don't rhyme  \r\nBut it's as good as, good as, good as, good as gold  \r\n[Verse 2]  \r\nGot a baby sister who looks just like me  \r\nShe wants nothing more than a man to please  \r\nMaybe she's in too deep  \r\nHer love for him ain't cheap  \r\nBut it breaks just like a knockoff piece  \r\nFrom Fulton Street  \r\nThe man's got a gift for getting what he wants  \r\nHe's thirsty when he drinks  \r\nGets on the brink, and throws her off  \r\nI get on my knees and beg you  \r\n  \r\n[Chorus]  \r\nHear my sinner's prayer  \r\nI am what I am  \r\nAnd I don't wanna break the heart of any other man  \r\nBut you, but you  \r\nHear my sinner's prayer  \r\nIt's the only one I know  \r\nIt sure as hell don't rhyme  \r\nBut it's as good as, good as, good as, good as gold  \r\nGood as, good as, good as, good as gold  \r\n  \r\n[Bridge]  \r\nI can carry you, but not your ghosts  \r\nWish I had the faith, but I don't know, oh  \r\n  \r\n[Chorus]  \r\nHear my sinner's prayer  \r\nI am what I am  \r\nAnd I don't wanna break the heart of any other man  \r\nBut you, but you  \r\nHear my sinner's prayer  \r\nIt's the only one I know  \r\nIt sure as hell don't rhyme  \r\nBut it's as good as, good as, good as, good as gold  \r\nGood as, good as, good as, good as gold  \r\nGood as, good as, good as, good as gold\r\n\r\n"

# %%
print(type(df['text']))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Text cleaning,Text preprocessing

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import string

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

def preprocess_text(text):
    # Tokenize the text into words
    tokens = word_tokenize(text)

    # Remove punctuation and lowercase
    tokens = [token.lower() for token in tokens if token not in string.punctuation]

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # stemmer = PorterStemmer()
    # tokens = [stemmer.stem(token) for token in tokens]

    return tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['text'] = [preprocess_text(sentence) for sentence in df['text']]
print(df['text'])
# Out:
# 0       [verse, 1, came, mountain, draggin, love, affa...
# 1       [margie, said, roy, ai, n't, listening, got, w...
# 2       [met, man, felt, way, world, passed, told, tro...
# 3       ['ve, come, long, way, car, road, went, narrow...
# 4       [life, hanging, balance, 're, dangling, thread...
#                               ...
# 9995    [maybe, 'm, old, fashioned, feeling, maybe, 'm...
# 9996    [somewhere, back, street, way, deep, back, sea...
# 9997    [oh, grand, illusion, like, fade, away, take, ...
# 9998    [maybe, 'm, right, maybe, 'm, wrong, got, go, ...
# 9999    [wake, sunday, morning, everything, feel, bori...
# Name: text, Length: 10000, dtype: object

# %%
df['text'][0]
# Out:
# ['verse',
#  '1',
#  'came',
#  'mountain',
#  'draggin',
#  'love',
#  'affair',
#  'put',
#  'pretty',
#  'little',
#  'number',
#  "'m",
#  'wearing',
#  'still',
#  'hell',
#  'scene',
#  'daddy',
#  "'s",
#  'feast',
#  'nobody',
#  'saw',
#  'coming',
#  'little',
#  'red',
#  'devil',
#  'funny',
#  'way',
#  'saying',
#  'forever',
#  'fast',
#  "n't",
#  'get',
#  'mad',
#  'ca',
#  "n't",
#  'blame',
#  'tramp',
#  'something',
#  "n't",
#  'get',
#  'knee',
#  'beg',
#  'chorus',
#  'hear',
#  'sinner',
#  "'s",
#  'prayer',
#  "n't",
#  'wan',
#  'na',
#  'break',
#  'heart',
#  'man',
#  'hear',
#  'sinner',
#  "'s",
#  'prayer',
#  "'s",
#  'one',
#  'know',
#  'sure',
#  'hell',
#  "n't",
#  'rhyme',
#  "'s",
#  'good',
#  'good',
#  'good',
#  'good',
#  'gold',
#  'verse',
#  '2',
#  'got',
#  'baby',
#  'sister',
#  'look',
#  'like',
#  'want',
#  'nothing',
#  'man',
#  'please',
#  'maybe',
#  "'s",
#  'deep',
#  'love',
#  'ai',
#  "n't",
#  'cheap',
#  'break',
#  'like',
#  'knockoff',
#  'piece',
#  'fulton',
#  'street',
#  'man',
#  "'s",
#  'got',
#  'gift',
#  'getting',
#  'want',
#  "'s",
#  'thirsty',
#  'drink',
#  'get',
#  'brink',
#  'throw',
#  'get',
#  'knee',
#  'beg',
#  'chorus',
#  'hear',
#  'sinner',
#  "'s",
#  'prayer',
#  "n't",
#  'wan',
#  'na',
#  'break',
#  'heart',
#  'man',
#  'hear',
#  'sinner',
#  "'s",
#  'prayer',
#  "'s",
#  'one',
#  'know',
#  'sure',
#  'hell',
#  "n't",
#  'rhyme',
#  "'s",
#  'good',
#  'good',
#  'good',
#  'good',
#  'gold',
#  'good',
#  'good',
#  'good',
#  'good',
#  'gold',
#  'bridge',
#  'carry',
#  'ghost',
#  'wish',
#  'faith',
#  "n't",
#  'know',
#  'oh',
#  'chorus',
#  'hear',
#  'sinner',
#  "'s",
#  'prayer',
#  "n't",
#  'wan',
#  'na',
#  'break',
#  'heart',
#  'man',
#  'hear',
#  'sinner',
#  "'s",
#  'prayer',
#  "'s",
#  'one',
#  'know',
#  'sure',
#  'hell',
#  "n't",
#  'rhyme',
#  "'s",
#  'good',
#  'good',
#  'good',
#  'good',
#  'gold',
#  'good',
#  'good',
#  'good',
#  'good',
#  'gold',
#  'good',
#  'good',
#  'good',
#  'good',
#  'gold']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'].apply(lambda x: ' '.join(x)))

# %%
matrix
# Out:
# <10000x30571 sparse matrix of type '<class 'numpy.float64'>'
# 	with 516877 stored elements in Compressed Sparse Row format>

# %%
similarity=cosine_similarity(matrix)

# %%
df[df['song'] == 'Hey Girl'].index[0]
# Out:
# 2424

# %%
similarity[1]
# Out:
# array([0.01639127, 1.        , 0.01616567, ..., 0.00452618, 0.03090761,
#        0.02169775])

# %%
df[df['song']=='America'].index[0]
# Out:
# 68

# %%
print(len(df['song']))
# Out:
# 10000

# %%
def recommendation(song_df):
  idx = df[df['song'] == song_df].index[0]
  distance = sorted(list(enumerate(similarity[idx])), reverse=True, key=lambda x: x[1])
  songs = []
  for m_id in distance[1:9]:
    songs.append(df.iloc[m_id[0]].song)
  songi = np.array(songs)
  return songi

recommendation('Goodbye Girl')
# Out:
# array(['Girl Goodbye', 'Goodbye', 'Goodbye Marlon Brando',
#        'Never Say Goodbye', 'Learn To Say Goodbye', 'Never Say Goodbye',
#        "Lookin' For That Girl", 'Goodbye For Now'], dtype='<U21')
